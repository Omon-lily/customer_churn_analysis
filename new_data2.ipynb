# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dirty = pd.read_excel("C:/Users/USER/Documents/Dirtydata.xlsx")

# %%
dirty
# Out:
#           Duration        Date    Pulse    Maxpulse   Calories
# 0               60  '2020/12/01'     110        130      409.1
# 1               60  '2020/12/02'     117        145      479.0
# 2               60  '2020/12/03'     103        135      340.0
# 3               45  '2020/12/04'     109        175      282.4
# 4               45  '2020/12/05'     117        148      406.0
# 5               60  '2020/12/06'     102        127      300.0
# 6               60  '2020/12/07'     110        136      374.0
# 7              450  '2020/12/08'     104        134      253.3
# 8               30  '2020/12/09'     109        133      195.1
# 9               60  '2020/12/10'      98        124      269.0
# 10              60  '2020/12/11'     103        147      329.3
# 11              60  '2020/12/12'     100        120      250.7
# 12              60  '2020/12/12'     100        120      250.7
# 13              60  '2020/12/13'     106        128      345.3
# ...

# %%
dirty.columns
# Out:
# Index(['      Duration', 'Date  ', 'Pulse ', ' Maxpulse', ' Calories'], dtype='object')

# %%
dirty.columns=dirty.columns.str.strip()
dirty.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
# 1. convert from string to date

# %%
dirty['Date']
# Out:
# 0     '2020/12/01'
# 1     '2020/12/02'
# 2     '2020/12/03'
# 3     '2020/12/04'
# 4     '2020/12/05'
# 5     '2020/12/06'
# 6     '2020/12/07'
# 7     '2020/12/08'
# 8     '2020/12/09'
# 9     '2020/12/10'
# 10    '2020/12/11'
# 11    '2020/12/12'
# 12    '2020/12/12'
# 13    '2020/12/13'
# 14    '2020/12/14'
# 15    '2020/12/15'
# 16    '2020/12/16'
# 17    '2020/12/17'
# 18    '2020/12/18'
# 19    '2020/12/19'
# 20    '2020/12/20'
# 21    '2020/12/21'
# 22             NaN
# 23    '2020/12/23'
# 24    '2020/12/24'
# 25    '2020/12/25'
# 26      2020/12/26
# 27    '2020/12/27'
# 28    '2020/12/28'
# 29    '2020/12/29'
# 30    '2020/12/30'
# 31    '2020/12/31'
# Name: Date, dtype: object

# %%
# 2. correcting Data Types:

# %%
#pd.to_datetime(dirty['Date']) ... converts string like '2023-01-01' to datetime format
dirty['Date'] = pd.to_datetime(dirty['Date'], errors='coerce')# convert to date, errors='coerce' will set invalid parsing as NaT

# %%
dirty['Date']
# Out:
# 0    2020-12-01
# 1    2020-12-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
# 5    2020-12-06
# 6    2020-12-07
# 7    2020-12-08
# 8    2020-12-09
# 9    2020-12-10
# 10   2020-12-11
# 11   2020-12-12
# 12   2020-12-12
# 13   2020-12-13
# 14   2020-12-14
# 15   2020-12-15
# 16   2020-12-16
# 17   2020-12-17
# 18   2020-12-18
# 19   2020-12-19
# 20   2020-12-20
# 21   2020-12-21
# 22          NaT
# 23   2020-12-23
# 24   2020-12-24
# 25   2020-12-25
# 26          NaT
# 27   2020-12-27
# 28   2020-12-28
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# Name: Date, dtype: datetime64[ns]

# %%
#correcting Data Types:
#dirty.astype() # convert to specified data type

# %%
dirty['Calories'] = dirty['Calories'].astype(float)

# %%
dirty['Calories'] =dirty['Calories'].astype('Int')# convert to integer, use 'Int64' for nullable integers

# %%
dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      30 non-null     datetime64[ns]
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.4 KB

# %%
# Remove duplicates:
dirty.drop_duplicates() # remove duplicate rows based on all or selected columns
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %%
di_unique = dirty.drop_duplicates()# create a new dataframe with duplicates removed
di_unique
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %% [markdown]
# dealing with missing data

# %%
di_unique.isnull().sum()# count of missing values in each column
# Out:
# Duration    0
# Date        2
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
dirty.dropna(subset=['Date'], inplace=True)# drop rows where 'Date' is NaT

# %%
dirty.dropna
# Out:
# <bound method DataFrame.dropna of     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
dirty_filled_mean = dirty['Calories'].fillna(dirty['Calories'].mean(),inplace=True)# fill missing 'Calories' with mean value
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25016\3827734275.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dirty_filled_mean = dirty['Calories'].fillna(dirty['Calories'].mean(),inplace=True)# fill missing 'Calories' with mean value

# %%
dirty
# Out:
#     Duration       Date  Pulse  Maxpulse    Calories
# 0         60 2020-12-01    110       130  409.100000
# 1         60 2020-12-02    117       145  479.000000
# 2         60 2020-12-03    103       135  340.000000
# 3         45 2020-12-04    109       175  282.400000
# 4         45 2020-12-05    117       148  406.000000
# 5         60 2020-12-06    102       127  300.000000
# 6         60 2020-12-07    110       136  374.000000
# 7        450 2020-12-08    104       134  253.300000
# 8         30 2020-12-09    109       133  195.100000
# 9         60 2020-12-10     98       124  269.000000
# 10        60 2020-12-11    103       147  329.300000
# 11        60 2020-12-12    100       120  250.700000
# 12        60 2020-12-12    100       120  250.700000
# 13        60 2020-12-13    106       128  345.300000
# 14        60 2020-12-14    104       132  379.300000
# 15        60 2020-12-15     98       123  275.000000
# 16        60 2020-12-16     98       120  215.200000
# ...

# %% [markdown]
# # data cleaning Assignment

# %%
import pandas as pd

# %%
cleaned = pd.read_excel("C:/Users/USER/Documents/data_cleaning.xlsx")

# %%
original = cleaned.copy()

# %%
cleaned
# Out:
#     Student_ID      Name     Age   Gender  Score Enrollment_Date  \
# 0          NaN       Eve  twenty        M    NaN             NaN
# 1          NaN     David      22     Male     75      2021/01/01
# 2        S0003       Eve      22        F  sixty             NaN
# 3        S0004     David      22   Female    200      2021-07-32
# 4        S0005     Alice      21  Unknown     50      03-20-2021
# ..         ...       ...     ...      ...    ...             ...
# 195      S0196       Bob      19        F     60      2021-02-15
# 196      S0197     frank      23     male     45      03-20-2021
# 197      S0198       Eve      21  Unknown     60      2021/01/01
# 198      S0199     Alice      20        M     70      2021-07-32
# 199      S0200       Eve     NaN   FEMALE     65      2021/01/01
#
#                Email           Phone        Department
# 0       eve@mail.com  +2348012345678      Data Science
# 1                NaN             NaN  Computer Science
# ...

# %%
cleaned.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Score', 'Enrollment_Date',
#        'Email', 'Phone', 'Department'],
#       dtype='object')

# %%
cleaned.isnull().sum()
# Out:
# Student_ID         11
# Name               27
# Age                13
# Gender             24
# Score              11
# Enrollment_Date    38
# Email              26
# Phone              36
# Department         28
# dtype: int64

# %%
original_isnull = original.isnull().sum()
# Out:
# np.int64(0)

# %%
original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student_ID       189 non-null    object
#  1   Name             173 non-null    object
#  2   Age              187 non-null    object
#  3   Gender           176 non-null    object
#  4   Score            189 non-null    object
#  5   Enrollment_Date  162 non-null    object
#  6   Email            174 non-null    object
#  7   Phone            164 non-null    object
#  8   Department       172 non-null    object
# dtypes: object(9)
# memory usage: 14.2+ KB

# %%
original.drop_duplicates()
# Out:
#     Student_ID      Name     Age   Gender  Score Enrollment_Date  \
# 0          NaN       Eve  twenty        M    NaN             NaN
# 1          NaN     David      22     Male     75      2021/01/01
# 2        S0003       Eve      22        F  sixty             NaN
# 3        S0004     David      22   Female    200      2021-07-32
# 4        S0005     Alice      21  Unknown     50      03-20-2021
# ..         ...       ...     ...      ...    ...             ...
# 195      S0196       Bob      19        F     60      2021-02-15
# 196      S0197     frank      23     male     45      03-20-2021
# 197      S0198       Eve      21  Unknown     60      2021/01/01
# 198      S0199     Alice      20        M     70      2021-07-32
# 199      S0200       Eve     NaN   FEMALE     65      2021/01/01
#
#                Email           Phone        Department
# 0       eve@mail.com  +2348012345678      Data Science
# 1                NaN             NaN  Computer Science
# ...

# %%
original.dropna()
# Out:
#     Student_ID      Name     Age   Gender Score Enrollment_Date  \
# 3        S0004     David      22   Female   200      2021-07-32
# 5        S0006     HeNry      30   Female    80      03-20-2021
# 7        S0008     HeNry      22     Male    80      2021-02-15
# 8        S0009     David      21     Male    80      2021/01/01
# 14       S0015     HeNry  twenty   FEMALE    80      2021-07-32
# ..         ...       ...     ...      ...   ...             ...
# 181      S0182     David      22     male    75      2021-07-32
# 182      S0183     jack       23     Male    70      03-20-2021
# 184      S0185    Grace       18     male    75      03-20-2021
# 196      S0197     frank      23     male    45      03-20-2021
# 197      S0198       Eve      21  Unknown    60      2021/01/01
#
#                     Email           Phone        Department
# 3         alice@gmail.com  +2348012345678      Comp Science
# 5    charlie[at]yahoo.com   080-1234-5678               ENG
# ...

# %%
original['Age'] = pd.to_numeric(original['Age'], errors='coerce').astype('Int64') # convert to integer, invalid entries become NaN

# %%
print(original['Age'])
# Out:
# 0      <NA>
# 1        22
# 2        22
# 3        22
# 4        21
#        ...
# 195      19
# 196      23
# 197      21
# 198      20
# 199    <NA>
# Name: Age, Length: 200, dtype: Int64

# %%
original
# Out:
#     Student_ID      Name   Age   Gender  Score Enrollment_Date  \
# 0          NaN       Eve  <NA>        M    NaN             NaN
# 1          NaN     David    22     Male     75      2021/01/01
# 2        S0003       Eve    22        F  sixty             NaN
# 3        S0004     David    22   Female    200      2021-07-32
# 4        S0005     Alice    21  Unknown     50      03-20-2021
# ..         ...       ...   ...      ...    ...             ...
# 195      S0196       Bob    19        F     60      2021-02-15
# 196      S0197     frank    23     male     45      03-20-2021
# 197      S0198       Eve    21  Unknown     60      2021/01/01
# 198      S0199     Alice    20        M     70      2021-07-32
# 199      S0200       Eve  <NA>   FEMALE     65      2021/01/01
#
#                Email           Phone        Department
# 0       eve@mail.com  +2348012345678      Data Science
# 1                NaN             NaN  Computer Science
# ...

# %%
original_isnull = original.isnull().sum()
original_isnull
# Out:
# Student_ID         11
# Name               27
# Age                32
# Gender             24
# Score              11
# Enrollment_Date    38
# Email              26
# Phone              36
# Department         28
# dtype: int64

# %%
original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student_ID       189 non-null    object
#  1   Name             173 non-null    object
#  2   Age              168 non-null    Int64
#  3   Gender           176 non-null    object
#  4   Score            189 non-null    object
#  5   Enrollment_Date  162 non-null    object
#  6   Email            174 non-null    object
#  7   Phone            164 non-null    object
#  8   Department       172 non-null    object
# dtypes: Int64(1), object(8)
# memory usage: 14.4+ KB

# %%
original.dropna()
# Out:
#     Student_ID      Name  Age   Gender  Score Enrollment_Date  \
# 3        S0004     David   22   Female    200      2021-07-32
# 5        S0006     HeNry   30   Female     80      03-20-2021
# 7        S0008     HeNry   22     Male     80      2021-02-15
# 8        S0009     David   21     Male     80      2021/01/01
# 31       S0032     David   30  Unknown     80      2021/01/01
# 38       S0039     HeNry   20        M  sixty      2021-02-15
# 42       S0043   Charlie   22  Unknown     45      03-20-2021
# 48       S0049   Charlie   23     male    200      2021/01/01
# 49       S0050    Grace    25        M     50      03-20-2021
# 52       S0053     David   21        M     55      2021/13/01
# 55       S0056     HeNry   19        F     60      03-20-2021
# 57       S0058     frank   19        F    200      2021/01/01
# 58       S0059     jack    23        M     65      03-20-2021
# 59       S0060     Alice   25   Female     60      2021-02-15
# ...

# %%
original['Enrollment_Date'] = pd.to_datetime(original['Enrollment_Date'], errors='coerce')

# %%
print(original['Enrollment_Date'])
# Out:
# 0            NaT
# 1     2021-01-01
# 2            NaT
# 3            NaT
# 4            NaT
#          ...
# 195          NaT
# 196          NaT
# 197   2021-01-01
# 198          NaT
# 199   2021-01-01
# Name: Enrollment_Date, Length: 200, dtype: datetime64[ns]

# %%
original
# Out:
#     Student_ID      Name   Age   Gender  Score Enrollment_Date  \
# 0          NaN       Eve  <NA>        M    NaN             NaT
# 1          NaN     David    22     Male     75      2021-01-01
# 2        S0003       Eve    22        F  sixty             NaT
# 3        S0004     David    22   Female    200             NaT
# 4        S0005     Alice    21  Unknown     50             NaT
# ..         ...       ...   ...      ...    ...             ...
# 195      S0196       Bob    19        F     60             NaT
# 196      S0197     frank    23     male     45             NaT
# 197      S0198       Eve    21  Unknown     60      2021-01-01
# 198      S0199     Alice    20        M     70             NaT
# 199      S0200       Eve  <NA>   FEMALE     65      2021-01-01
#
#                Email           Phone        Department
# 0       eve@mail.com  +2348012345678      Data Science
# 1                NaN             NaN  Computer Science
# ...

# %%
original.dropna()
# Out:
#     Student_ID      Name  Age   Gender  Score Enrollment_Date  \
# 8        S0009     David   21     Male     80      2021-01-01
# 31       S0032     David   30  Unknown     80      2021-01-01
# 48       S0049   Charlie   23     male    200      2021-01-01
# 57       S0058     frank   19        F    200      2021-01-01
# 68       S0069     Alice   19   Female     70      2021-01-01
# 91       S0092     Alice   22        F  sixty      2021-01-01
# 96       S0097     jack    23     male     50      2021-01-01
# 131      S0132     David   19        F     70      2021-01-01
# 133      S0134   Charlie   30   FEMALE     55      2021-01-01
# 137      S0138     frank   18   FEMALE    200      2021-01-01
# 145      S0146     Alice   22     Male     60      2021-01-01
# 150      S0151       IVY   23        M  sixty      2021-01-01
# 154      S0155    Grace    22     male     80      2021-01-01
# 163      S0164     Alice   23        M     70      2021-01-01
# ...

# %% [markdown]
# # …or create a new repository on the command line
# echo "# new_data2" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/Omon-lily/new_data2.git
# git push -u origin main
